# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiMeghanaGoud/EDA-capstone-project/blob/main/Copy_of_Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %% [markdown]
# **WHAT IS EXPLORATORY DATA ANALYSIS**
# A data exploration technique to understand the various aspects of the data and make conclusions about the given data.
#
# **LET'S HAVE LOOK ON SOME OBJECTIVES OF EDA**
#
# *  Filter the data from redundancies
# * Build relationships between the variables
#
# **STEPS INVOLVED IN EDA**
# *   Understand the data
# *   Clean the data
# *   Analyssis of relationship between the variables

# %% [markdown]
# The purpose of this EDA is to find potential features that are  correlated to churn customer data.
#
# The data contains:
#
# Customer demographic data : gender, SeniorCitizen, Partner,
#
# Dependents
# Service provided by Telco and customer subscribe data : PhoneService, MultipleLines, InternetService, OnlineSecurity, DeviceProtection, TechSupport, StreamingTV, StreamingMovies
#
#
# Customer account information : tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges and TotalCharges
#
# Churn data customer within the last month

# %% [markdown]
# Churn is major problem in any industry such problem is also observed in telecom industry. In given data we are looking for churn analysis for given data we first perform EDA and then by comparing various elements such as rates, voice mail, voice messages, international calls etc. By means of doing this analysis we can go for conclusion where is churn rate is high why customers are leaving. For a telecom industry it is very hard to acquire new customers so they should focus on how to retain existing customers.If the churn rate of company is 50% then the company will be going to shut in two years. As company with churn rate 25% then it will shut in four years so Churn is the major factor to be taken in consideration.

# %% [markdown]
# **Let us import the liabreries and .csv file into Notebook, after that let us perform basic operations such as info and describe**

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing Dataset
df = pd.read_csv('/content/drive/MyDrive/almabetter/eda telecom churn analysis/Copy of Telecom Churn.csv')

# %% [markdown]
# **Having look on our dataset**

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.tail(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# From above two cells we can say that there are no missing values

# %% [markdown]
# Duplicate rows

# %%
#checking for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# In order to understand our data, we can look at each variable and try to understand their meaning and relevance to this problem.
#
# First, we try to understand what each variable means -
#
# 1.State - 51 Unique States in the United States of America (Categorical)
#
# 2.Account Length - Length of The Account
#
# 3.Area Code - 415 relates to San Francisco,408 is of San Jose and 510 is of the city of Okland (Categorical)
#
# 4.International Plan - Yes Indicate International Plan is Present and No Indicates no subscription for International Plan (Categorical)
#
# 5.Voice mail plan - Yes Indicates Voice Mail Plan is Present and No Indicates no subscription for Voice Mail Plan (Categorical)
#
# 6.Number vmail messages - Number of Voice Mail Messages ranging from 0 to 50
#
# 7.Total day minutes - Total Number of Minutes Spent By Customers in Morning
#
# 8.Total day calls - Total Number of Calls made by Customer in Morning
#
# 9.Total day charge - Total Charge to the Customers in Morning
#
# 10.Total eve minutes - Total Number of Minutes Spent By Customers in Evening
#
# 11.Total eve calls - Total Number of Calls made by Customer in Evening
#
# 12.Total eve charge - Total Charge to the Customers in Evening
#
# 13.Total night minutes - Total Number of Minutes Spent By Customers in the Night
#
# 14.Total night calls - Total Number of Calls made by Customer in Night
#
# 15.Total night charge - Total Charge to the Customers in Night
#
# 16.Total intl minutes - Total Number of Minutes Spent By Customers on international calls
#
# 17.Total intl calls- Total Number of international Calls made by Customer
#
# 18.Total intl charge - Total Charge to the Customers on international calls
#
# 19.Customer service calls - Total numbers of calls to customer service
#
#
# Churn - True indicate that customers don't continue with the subscription and False indicates customers continue with the subscription. (Categorical)
# Here we will analyze the key factors responsible for customers leaving the subscription. We will check each variable and its dependency on the Churn variable.

# %%
#exploring the dataset
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# check unique values of each column
unique_column_values = {}
for column in df.columns:
  value = {'column_name':column, 'frquency': len(df[column].unique())}
  unique_column_values[column] = value
pd.DataFrame(unique_column_values.values()).sort_values('frquency')
# Out:
#                column_name  frquency
# 19                   Churn         2
# 3       International plan         2
# 4          Voice mail plan         2
# 2                Area code         3
# 18  Customer service calls        10
# 16        Total intl calls        21
# 5    Number vmail messages        46
# 0                    State        51
# 7          Total day calls       119
# 13       Total night calls       120
# 10         Total eve calls       123
# 15      Total intl minutes       162
# 17       Total intl charge       162
# 1           Account length       212
# 14      Total night charge       933
# 11        Total eve charge      1440
# 12     Total night minutes      1591
# 9        Total eve minutes      1611
# 8         Total day charge      1667
# 6        Total day minutes      1667

# %% [markdown]
# After observing the dataset  a few assumptions before proceeding further:
#
# The dataset is for a particular date and is for only one day.
#
#  The customers who have left the subscription will never return.
#
# From the dataset, we can see that call time is in minutes. From the 3 columns (Total day minutes, Total eve minutes & Total night minutes) the maximum talk time is 363 minutes (~6 hours). So we can assume that the dataset is for a particular date.
#
# The dataset has all 51 states of the USA and has customers. So, the telecom company expanded to the whole USA. But there are only 3333 customers that are very small compared to the USA population. Thus we can assume that the dataset is a part of the whole USA dataset.

# %% [markdown]
# **Diving deep into data**

# %%
corr=df.corr().round(2)
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot = True)

# %% [markdown]
# we can see strong correlation between the variables:
#
# Total day minutes vs total day charge
#
# Total eve minues vs total eve charge
#
# Total night minutes vs total night charge
#
# Total intl minutes vs total intl charge
#
# Therefore we can choose any one variable from each pair for analyzing the churn.

# %%
#Churn' is our dependent variable. We will analyse churn to get some insight into it.
sns.countplot(df['Churn'],palette='rocket')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='State', hue="Churn", data= df)
plt.rcParams['figure.figsize'] = (12, 7)

# %% [markdown]
# We can observe that few customers are leaving the subscription. Let's calculate the percentage of churn.

# %%
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
# calculate churn percentage
df_churn = pd.DataFrame(df['Churn'].value_counts())
df_churn.Churn[1]/(df_churn.Churn[0]+df_churn.Churn[1])*100
# Out:
# 14.491449144914492

# %%
df ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for Churn')
plt.show()

# %% [markdown]
# t can be seen that almost 14.5% of customers are leaving the subscription.
#
# Since the data has 19 independent variables, it will take time to analyze every variable. So, we will find the correlation between Churn and other continuous variables and analyze those variables that have a high correlation to Churn.

# %%
df.corr()['Churn'][:-1].sort_values(ascending=False)
# Out:
# Customer service calls    0.208750
# Total day minutes         0.205151
# Total day charge          0.205151
# Total eve minutes         0.092796
# Total eve charge          0.092786
# Total intl charge         0.068259
# Total intl minutes        0.068239
# Total night charge        0.035496
# Total night minutes       0.035493
# Total day calls           0.018459
# Account length            0.016541
# Total eve calls           0.009233
# Area code                 0.006174
# Total night calls         0.006141
# Total intl calls         -0.052844
# Number vmail messages    -0.089728
# Name: Churn, dtype: float64

# %% [markdown]
# let us see top 10 states who are moving towards churn

# %%
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(10).plot.bar(color = ['violet','indigo','b','g','y','orange','r'])
plt.title(" State with most churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 15)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# Here we can see states NJ ans CA have same churn percentage. plot churn percentage pi plot of CA state for that we have to take CA state seperate

# %%
state_CA =df[df['State']=='CA']

# %%
state_CA
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 61      CA             116        415                 No             Yes
# 131     CA              75        408                 No              No
# 356     CA             124        408                Yes              No
# 372     CA             151        415                Yes              No
# 496     CA              93        415                 No             Yes
# 654     CA              96        510                 No             Yes
# 655     CA              79        510                 No              No
# 765     CA             113        415                 No              No
# 862     CA              75        510                 No             Yes
# 954     CA             158        510                 No              No
# 1038    CA             112        415                 No              No
# 1158    CA              60        415                Yes              No
# ...

# %%
state_CA ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(10,10))
plt.title('Pie Chart for Churn values')
plt.show()

# %% [markdown]
# As we see top 10 states which are moving towards churn let us see last 10 states which are moving towards churn

# %%
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = True).head(10).plot.bar(color = ['b','indigo','violet','orange','y','g','r'])
plt.title(" State with least churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 25)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# From graph we can see least percentage of cgurn is in state HI let us plot churn percentage plot for HI

# %%
state_HI =df[df['State']=='HI']

# %%
state_HI ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(10,10))
plt.title('Pie Chart for Churn values for state HI')
plt.show()

# %% [markdown]
# For custumers to churn there may be more reasons one of the reason is Rates of calls let us compare all call rate

# %%
day_mean = df['Total day charge'].mean()/df['Total day minutes'].mean()
eve_mean = df['Total eve charge'].mean()/df['Total eve minutes'].mean()
night_mean = df['Total night charge'].mean()/df['Total night minutes'].mean()
int_mean = df['Total intl charge'].mean()/df['Total intl minutes'].mean()

# %%
print([day_mean,eve_mean,night_mean,int_mean])
# Out:
# [0.1700030073913066, 0.08500104871485774, 0.04500041448440013, 0.2700500279887098]

# %%
sns.barplot(x=['Day','Evening','Night','International'],y=[day_mean,eve_mean,night_mean,int_mean])

# %% [markdown]
# From graph we can see that International plans have more rate as compare to oters. By putting Bar plot in total minutes and state we can see how many minutes are used in day. As well as we will put multi-line plot in between Total day minutes, Total eve minutes, Total night minutes, Total intl minutes

# %%
avg_total_day_minutes = df.groupby(['State'])['Total day minutes'].mean()

# %%
avg_total_day_minutes
# Out:
# State
# AK    178.384615
# AL    186.010000
# AR    176.116364
# AZ    171.604688
# CA    183.564706
# CO    178.712121
# CT    175.140541
# DC    171.379630
# DE    174.583607
# FL    179.533333
# GA    185.025926
# HI    175.962264
# IA    177.613636
# ID    178.619178
# IL    173.591379
# IN    196.525352
# KS    191.555714
# KY    173.754237
# LA    178.376471
# MA    180.103077
# MD    197.228571
# ME    185.262903
# MI    180.593151
# MN    183.354762
# MO    170.506349
# MS    177.929231
# MT    174.007353
# NC    185.145588
# ND    187.338710
# NE    177.465574
# NH    177.328571
# NJ    196.225000
# NM    171.429032
# NV    176.425758
# NY    175.114458
# OH    183.274359
# OK    179.909836
# OR    176.246154
# PA    188.375556
# RI    167.478462
# SC    166.441667
# SD    189.690000
# TN    175.771698
# TX    181.516667
# UT    183.569444
# VA    177.244156
# VT    182.031507
# WA    178.742424
# WI    179.130769
# WV    173.950943
# WY    180.170130
# ...

# %%
avg_total_day_minutes.plot(kind='bar')

plt.title('Avg total day minutes')
plt.ylabel('Avg minutes')
plt.xlabel('State')
plt.rcParams['figure.figsize'] = (20,10)

# %%
avg_total_minutes = df.groupby(['State'])['Total day minutes','Total eve minutes','Total night minutes', 'Total intl minutes'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
print(avg_total_minutes)
# Out:
#        Total day minutes  Total eve minutes  Total night minutes  \
# State
# AK            178.384615         184.282692           192.326923
# AL            186.010000         195.462500           187.285000
# AR            176.116364         201.047273           205.454545
# AZ            171.604688         187.748437           194.004687
# CA            183.564706         198.970588           198.508824
# CO            178.712121         206.884848           189.898485
# CT            175.140541         203.828378           205.997297
# DC            171.379630         196.272222           206.348148
# DE            174.583607         208.247541           203.900000
# FL            179.533333         210.276190           196.147619
# GA            185.025926         204.140741           193.746296
# HI            175.962264         191.343396           203.713208
# IA            177.613636         206.400000           191.490909
# ...

# %%
avg_total_minutes.plot()

plt.title('Avg total minutesin a day')
plt.ylabel('Number of Minutes')
plt.xlabel('State')
plt.rcParams['figure.figsize'] = (20, 10)

# %% [markdown]
# From the graph below we can see Revenue for company means which type of day charge generates more revenue. The line for International calls is as bottom from this we can say Price for International calls is high but due to low usage Revenue generated is low

# %%
avg_total_value = df.groupby(['State'])['Total day charge','Total eve charge','Total night charge', 'Total intl charge'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
print(avg_total_value)
# Out:
#        Total day charge  Total eve charge  Total night charge  \
# State
# AK            30.325769         15.664231            8.654808
# AL            31.621500         16.614500            8.427875
# AR            29.940000         17.089636            9.245818
# AZ            29.173125         15.958906            8.730625
# CA            31.206176         16.913529            8.932941
# CO            30.381818         17.584848            8.546061
# CT            29.774324         17.325946            9.270405
# DC            29.135370         16.684074            9.285741
# DE            29.680164         17.701311            9.175574
# FL            30.521429         17.873651            8.826508
# GA            31.455185         17.352222            8.718519
# HI            29.913019         16.263774            9.166792
# IA            30.195455         17.544318            8.617955
# ID            30.365753         16.542055            9.116986
# ...

# %%
avg_total_value.plot()
plt.title('Avg total value')
plt.ylabel('Avg prices')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# Let see relation between churn and Total day minutes, Total eve minutes, Total night minutes and Total intl minutes with respect to Churn by scatter plot <h3

# %%
sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", data= df,palette='hls')

# %%
sns.scatterplot(x="Total eve minutes", y="Total eve charge", hue="Churn", data= df,palette='hls')

# %%
sns.scatterplot(x="Total night minutes", y="Total night charge", hue="Churn", data= df,palette='hls')

# %%
sns.scatterplot(x="Total intl minutes", y="Total intl charge", hue="Churn", data= df,palette='hls')

# %% [markdown]
# Let us see the relation between International plan, Voice mail plan and Customer service calls with respect to Churn by bar plot

# %%
sns.countplot(x='International plan',hue="Churn",data = df)

# %%
sns.countplot(x='Voice mail plan',hue="Churn",data = df)

# %%
sns.countplot(x='Customer service calls',hue="Churn",data = df)

# %% [markdown]
# By creating a function in between x and y we can manipulate many columns

# %%
def diff_bar(x,y):
    
    df.groupby([x,y]).size().unstack(level=-1).plot(kind='bar',figsize=(35,10))
    plt.xlabel('x',fontsize = 25)
    plt.ylabel('count',fontsize = 25)
    plt.legend(loc=0,fontsize=25)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.title("Analyzing State Column",fontsize = 40)
    plt.show()

# %%
diff_bar('State','Customer service calls')

# %%
diff_bar('State','Churn')

# %%
diff_bar('State','International plan')

# %%
diff_bar('State','Voice mail plan')

# %% [markdown]
# By putting Heat map and histogram simultanously we can co-relate with columns

# %%
churn_data_df = df [['Account length','Area code','International plan','Voice mail plan','Number vmail messages','Total day minutes','Total day calls','Total day charge','Total eve minutes','Total eve calls','Total eve charge','Total night minutes','Total night calls','Total night charge','Total intl minutes','Total intl calls','Total intl charge','Customer service calls','Churn']]

# %%
corr_df = churn_data_df.corr()

# %%
corr_df
# Out:
#                         Account length  Area code  Number vmail messages  \
# Account length                1.000000  -0.012463              -0.004628
# Area code                    -0.012463   1.000000              -0.001994
# Number vmail messages        -0.004628  -0.001994               1.000000
# Total day minutes             0.006216  -0.008264               0.000778
# Total day calls               0.038470  -0.009646              -0.009548
# Total day charge              0.006214  -0.008264               0.000776
# Total eve minutes            -0.006757   0.003580               0.017562
# Total eve calls               0.019260  -0.011886              -0.005864
# Total eve charge             -0.006745   0.003607               0.017578
# Total night minutes          -0.008955  -0.005825               0.007681
# Total night calls            -0.013176   0.016522               0.007123
# Total night charge           -0.008960  -0.005845               0.007663
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_df)

# %%
fig, ax = plt.subplots(figsize=(15,15))
pd.DataFrame.hist(df,ax=ax)
plt.tight_layout();
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
